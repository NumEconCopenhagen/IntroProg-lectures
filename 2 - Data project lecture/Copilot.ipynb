# %%
# %load_ext autoreload
# %autoreload 2

# %%
from copilot import StockData

# %%
SD = StockData('GOOG')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Open         High          Low        Close    Adj Close  \
# count  4942.000000  4942.000000  4942.000000  4942.000000  4942.000000
# mean     43.211732    43.669406    42.777703    43.232953    43.232953
# std      40.479799    40.937455    40.076764    40.515883    40.515883
# min       2.470490     2.534002     2.390042     2.490913     2.490913
# 25%      12.934829    13.055004    12.804381    12.928167    12.928167
# 50%      26.806090    26.978463    26.583760    26.776734    26.776734
# 75%      58.959125    59.484124    58.347501    58.931751    58.931751
# max     155.080002   157.000000   154.132004   156.500000   156.500000
#
#              Volume  Adj Close RM 200  Adj Close RM 50        Cross  \
# count  4.942000e+03       4743.000000      4893.000000  4942.000000
# mean   1.172842e+08         42.009795        42.917080     0.005059
# ...

# %%
SD.plot(start_year=2020,end_year=2024)

# %%
SD.plot(start_year=2020,end_year=2024,variables=['Cumulative Return','Alternative Cumulative Return'])
